# %% [markdown]
# <a href="https://colab.research.google.com/github/yashfx/Internship-Fx-data-labs/blob/Supervised-learning-problem-%22credit-card-fraud-detection%22/Credit_fraud_detection_using_LR%2CSVM%2CDT.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Importing the libraries

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import pickle
from sklearn.linear_model import LogisticRegression
from sklearn.svm import SVC
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score

# %% [markdown]
# Reading the dataset

# %%
df = pd.read_csv(r"D:\Internship Fx data labs\Day 9\creditcard.csv")

# %%
df.head()
# Out:
#    Time        V1        V2        V3        V4        V5        V6        V7  \
# 0   0.0 -1.359807 -0.072781  2.536347  1.378155 -0.338321  0.462388  0.239599
# 1   0.0  1.191857  0.266151  0.166480  0.448154  0.060018 -0.082361 -0.078803
# 2   1.0 -1.358354 -1.340163  1.773209  0.379780 -0.503198  1.800499  0.791461
# 3   1.0 -0.966272 -0.185226  1.792993 -0.863291 -0.010309  1.247203  0.237609
# 4   2.0 -1.158233  0.877737  1.548718  0.403034 -0.407193  0.095921  0.592941
#
#          V8        V9  ...       V21       V22       V23       V24       V25  \
# 0  0.098698  0.363787  ... -0.018307  0.277838 -0.110474  0.066928  0.128539
# 1  0.085102 -0.255425  ... -0.225775 -0.638672  0.101288 -0.339846  0.167170
# 2  0.247676 -1.514654  ...  0.247998  0.771679  0.909412 -0.689281 -0.327642
# 3  0.377436 -1.387024  ... -0.108300  0.005274 -0.190321 -1.175575  0.647376
# 4 -0.270533  0.817739  ... -0.009431  0.798278 -0.137458  0.141267 -0.206010
#
# ...

# %%
df.tail()
# Out:
#             Time         V1         V2        V3        V4        V5  \
# 284802  172786.0 -11.881118  10.071785 -9.834783 -2.066656 -5.364473
# 284803  172787.0  -0.732789  -0.055080  2.035030 -0.738589  0.868229
# 284804  172788.0   1.919565  -0.301254 -3.249640 -0.557828  2.630515
# 284805  172788.0  -0.240440   0.530483  0.702510  0.689799 -0.377961
# 284806  172792.0  -0.533413  -0.189733  0.703337 -0.506271 -0.012546
#
#               V6        V7        V8        V9  ...       V21       V22  \
# 284802 -2.606837 -4.918215  7.305334  1.914428  ...  0.213454  0.111864
# 284803  1.058415  0.024330  0.294869  0.584800  ...  0.214205  0.924384
# 284804  3.031260 -0.296827  0.708417  0.432454  ...  0.232045  0.578229
# 284805  0.623708 -0.686180  0.679145  0.392087  ...  0.265245  0.800049
# 284806 -0.649617  1.577006 -0.414650  0.486180  ...  0.261057  0.643078
#
#              V23       V24       V25       V26       V27       V28  Amount  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 284807 entries, 0 to 284806
# Data columns (total 31 columns):
#  #   Column  Non-Null Count   Dtype
# ---  ------  --------------   -----
#  0   Time    284807 non-null  float64
#  1   V1      284807 non-null  float64
#  2   V2      284807 non-null  float64
#  3   V3      284807 non-null  float64
#  4   V4      284807 non-null  float64
#  5   V5      284807 non-null  float64
#  6   V6      284807 non-null  float64
#  7   V7      284807 non-null  float64
#  8   V8      284807 non-null  float64
#  9   V9      284807 non-null  float64
#  10  V10     284807 non-null  float64
#  11  V11     284807 non-null  float64
#  12  V12     284807 non-null  float64
#  13  V13     284807 non-null  float64
#  14  V14     284807 non-null  float64
#  15  V15     284807 non-null  float64
#  16  V16     284807 non-null  float64
#  17  V17     284807 non-null  float64
#  18  V18     284807 non-null  float64
#  19  V19     284807 non-null  float64
# ...

# %%
df.describe()
# Out:
#                 Time            V1            V2            V3            V4  \
# count  284807.000000  2.848070e+05  2.848070e+05  2.848070e+05  2.848070e+05
# mean    94813.859575  1.168375e-15  3.416908e-16 -1.379537e-15  2.074095e-15
# std     47488.145955  1.958696e+00  1.651309e+00  1.516255e+00  1.415869e+00
# min         0.000000 -5.640751e+01 -7.271573e+01 -4.832559e+01 -5.683171e+00
# 25%     54201.500000 -9.203734e-01 -5.985499e-01 -8.903648e-01 -8.486401e-01
# 50%     84692.000000  1.810880e-02  6.548556e-02  1.798463e-01 -1.984653e-02
# 75%    139320.500000  1.315642e+00  8.037239e-01  1.027196e+00  7.433413e-01
# max    172792.000000  2.454930e+00  2.205773e+01  9.382558e+00  1.687534e+01
#
#                  V5            V6            V7            V8            V9  \
# count  2.848070e+05  2.848070e+05  2.848070e+05  2.848070e+05  2.848070e+05
# mean   9.604066e-16  1.487313e-15 -5.556467e-16  1.213481e-16 -2.406331e-15
# ...

# %%
df['Class'].value_counts()
# Out:
# 0    284315
# 1       492
# Name: Class, dtype: int64

# %%
#print(df[df['Class'] == 1].head())

# %% [markdown]
# Preprocessing the data

# %%
fraud=df[df["Class"]==1]
not_fraud=df[df["Class"]==0]

# %%
print(fraud)
print(not_fraud)
# Out:
#             Time        V1        V2        V3        V4        V5        V6  \
# 541        406.0 -2.312227  1.951992 -1.609851  3.997906 -0.522188 -1.426545
# 623        472.0 -3.043541 -3.157307  1.088463  2.288644  1.359805 -1.064823
# 4920      4462.0 -2.303350  1.759247 -0.359745  2.330243 -0.821628 -0.075788
# 6108      6986.0 -4.397974  1.358367 -2.592844  2.679787 -1.128131 -1.706536
# 6329      7519.0  1.234235  3.019740 -4.304597  4.732795  3.624201 -1.357746
# ...          ...       ...       ...       ...       ...       ...       ...
# 279863  169142.0 -1.927883  1.125653 -4.518331  1.749293 -1.566487 -2.010494
# 280143  169347.0  1.378559  1.289381 -5.004247  1.411850  0.442581 -1.326536
# 280149  169351.0 -0.676143  1.126366 -2.213700  0.468308 -1.120541 -0.003346
# 281144  169966.0 -3.113832  0.585864 -5.399730  1.817092 -0.840618 -2.943548
# 281674  170348.0  1.991976  0.158476 -2.583441  0.408670  1.151147 -0.096695
#
# ...

# %%
fraud.Amount.describe()
# Out:
# count     492.000000
# mean      122.211321
# std       256.683288
# min         0.000000
# 25%         1.000000
# 50%         9.250000
# 75%       105.890000
# max      2125.870000
# Name: Amount, dtype: float64

# %%
not_fraud.Amount.describe()
# Out:
# count    284315.000000
# mean         88.291022
# std         250.105092
# min           0.000000
# 25%           5.650000
# 50%          22.000000
# 75%          77.050000
# max       25691.160000
# Name: Amount, dtype: float64

# %%
not_fraud=not_fraud.sample(n=400)
not_fraud
# Out:
#             Time        V1        V2        V3        V4        V5        V6  \
# 21706    31816.0 -2.363569 -1.769231  1.588523  2.237558  0.991421 -0.122157
# 135391   81231.0 -0.582629  0.949019 -0.138487 -1.266682  2.410342  3.350199
# 201129  133740.0  1.879807 -0.625337 -0.599315  0.402055 -0.461161  0.009638
# 202945  134566.0  1.852993 -0.085116 -1.730941  1.227152  0.594130 -0.366098
# 78186    57405.0 -0.243484  0.578752  1.654349 -0.641673 -0.319095 -0.947719
# ...          ...       ...       ...       ...       ...       ...       ...
# 102997   68451.0  1.094993 -0.275047  0.601400  0.621894 -0.607042  0.086386
# 191002  129068.0 -0.551559  1.220283 -0.398635 -0.741437  0.715349 -0.785953
# 139898   83418.0 -0.579719  1.037126  1.714659  2.532502  0.087476  0.667692
# 100701   67595.0  1.178768 -0.040746  1.028326  0.648021 -1.083981 -0.942981
# 93079    64241.0  1.301473 -1.420483  0.830972 -1.206078 -1.791653  0.027971
#
# ...

# %%
palanced_dataset=pd.concat([fraud,not_fraud],axis=0)
palanced_dataset
# Out:
#             Time        V1        V2        V3        V4        V5        V6  \
# 541        406.0 -2.312227  1.951992 -1.609851  3.997906 -0.522188 -1.426545
# 623        472.0 -3.043541 -3.157307  1.088463  2.288644  1.359805 -1.064823
# 4920      4462.0 -2.303350  1.759247 -0.359745  2.330243 -0.821628 -0.075788
# 6108      6986.0 -4.397974  1.358367 -2.592844  2.679787 -1.128131 -1.706536
# 6329      7519.0  1.234235  3.019740 -4.304597  4.732795  3.624201 -1.357746
# ...          ...       ...       ...       ...       ...       ...       ...
# 102997   68451.0  1.094993 -0.275047  0.601400  0.621894 -0.607042  0.086386
# 191002  129068.0 -0.551559  1.220283 -0.398635 -0.741437  0.715349 -0.785953
# 139898   83418.0 -0.579719  1.037126  1.714659  2.532502  0.087476  0.667692
# 100701   67595.0  1.178768 -0.040746  1.028326  0.648021 -1.083981 -0.942981
# 93079    64241.0  1.301473 -1.420483  0.830972 -1.206078 -1.791653  0.027971
#
# ...

# %%
palanced_dataset["Class"].value_counts()
# Out:
# 1    492
# 0    400
# Name: Class, dtype: int64

# %% [markdown]
# Splitting the data

# %%
x=palanced_dataset.drop("Class",axis='columns')
y=palanced_dataset["Class"]

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,stratify=y,random_state=2)

# %% [markdown]
# Building the model

# %%
logs_model=LogisticRegression()
logs_model.fit(x_train,y_train)
# Out:
# LogisticRegression()

# %%
y_predict=logs_model.predict(x_test)

# %% [markdown]
# Evaluating the model

# %%
from sklearn.metrics import precision_score,recall_score, confusion_matrix , classification_report
accuracy=accuracy_score(y_test,y_predict)
print("Accuracy= ",int(accuracy*100),'%')
precision = precision_score(y_test, y_predict)
print("Precision= ",int(precision*100),"%")
recall = recall_score(y_test, y_predict)
print("Recall= ",int(recall*100),"%")
cm = confusion_matrix(y_test, y_predict)
print("Confusion Matrix:")
print(cm)
report = classification_report(y_test, y_predict)
print("Classification Report:")
print(report)
# Out:
# Accuracy=  89 %
# Precision=  100 %
# Recall=  81 %
# Confusion Matrix:
# [[80  0]
#  [18 81]]
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.82      1.00      0.90        80
#            1       1.00      0.82      0.90        99
#
#     accuracy                           0.90       179
#    macro avg       0.91      0.91      0.90       179
# weighted avg       0.92      0.90      0.90       179

# %%
#pickle.dump(logs_model, open('logs_model.pkl', 'wb'))

# %%
#pickled_model = pickle.load(open('logs_model.pkl', 'rb'))
#pickled_model.predict(x_test)

# %%
import joblib

# Save the model to a file
joblib.dump(logs_model, 'credit_card_fraud_model6.pkl')
# Out:
# ['credit_card_fraud_model6.pkl']

# %%
x_train.shape
# Out:
# (713, 30)

# %%
svm_classifier = SVC(kernel = "linear", C=3)
svm_classifier.fit(x_train,y_train)
# Out:
# SVC(C=3, kernel='linear')

# %%
from sklearn.metrics import precision_score, recall_score , confusion_matrix , classification_report
y_predict=svm_classifier.predict(x_test)
accuracy=accuracy_score(y_test,y_predict)
print("Accuracy= ",int(accuracy*100),'%')
precision = precision_score(y_test, y_predict)
print("Precision= ",int(precision*100),"%")
recall = recall_score(y_test, y_predict)
print("Recall= ",int(recall*100),"%")
cm = confusion_matrix(y_test, y_predict)
print("Confusion Matrix:")
print(cm)
report = classification_report(y_test, y_predict)
print("Classification Report:")
print(report)
# Out:
# Accuracy=  89 %
# Precision=  100 %
# Recall=  81 %
# Confusion Matrix:
# [[80  0]
#  [18 81]]
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.82      1.00      0.90        80
#            1       1.00      0.82      0.90        99
#
#     accuracy                           0.90       179
#    macro avg       0.91      0.91      0.90       179
# weighted avg       0.92      0.90      0.90       179

# %%
import joblib

joblib.dump(svm_classifier,'credit_card_fraud_model7.pkl')
# Out:
# ['credit_card_fraud_model7.pkl']

# %%
from sklearn.tree import DecisionTreeClassifier

# %%
tree_model = DecisionTreeClassifier(random_state=1)
tree_model.fit(x_train, y_train)
# Out:
# DecisionTreeClassifier(random_state=1)

# %%
y_predict = tree_model.predict(x_test)
accuracy=accuracy_score(y_test,y_predict)
print("Accuracy= ",int(accuracy*100),'%')
precision = precision_score(y_test, y_predict)
print("Precision= ",int(precision*100),"%")
recall = recall_score(y_test, y_predict)
print("Recall= ",int(recall*100),"%")
cm = confusion_matrix(y_test, y_predict)
print("Confusion Matrix:")
print(cm)
report = classification_report(y_test, y_predict)
print("Classification Report:")
print(report)
# Out:
# Accuracy=  90 %
# Precision=  88 %
# Recall=  94 %
# Confusion Matrix:
# [[68 12]
#  [ 5 94]]
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.93      0.85      0.89        80
#            1       0.89      0.95      0.92        99
#
#     accuracy                           0.91       179
#    macro avg       0.91      0.90      0.90       179
# weighted avg       0.91      0.91      0.90       179

# %%
import joblib

joblib.dump(tree_model,'credit_card_fraud_model8.pkl')
# Out:
# ['credit_card_fraud_model8.pkl']
